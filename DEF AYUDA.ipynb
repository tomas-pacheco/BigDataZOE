# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#filtrado 2004
ruta = r"/Users/zowi/Desktop/Big Data/GitHub/BigData/t104_dta/Individual_t104.dta"
df_2004 = pd.read_stata(ruta, convert_categoricals=True)

print("Valores en región", df_2004['region'].unique())

df_2004 = df_2004[df_2004['region'] == "NOA"]

print ("Dataframe", df_2004.shape)

print(df_2004.head())

df_2004.to_stata(r"/Users/zowi/Desktop/Big Data/GitHub/BigData/t104_dta/Individual_t104.dta", write_index=False)
# Out:
# Valores en región ['Gran Buenos Aires', 'NOA', 'NEA', 'Cuyo', 'Pampeana', 'Patagónica']
# Categories (6, object): ['Gran Buenos Aires' < 'NOA' < 'NEA' < 'Cuyo' < 'Pampeana' < 'Patagónica']
# Dataframe (9393, 176)
#         CODUSU  nro_hogar componente h15    ano4       trimestre region  \
# 7647  125624          1.0        1.0  Sí  2004.0  1er. Trimestre    NOA
# 7648  125666          1.0        1.0  Sí  2004.0  1er. Trimestre    NOA
# 7649  125666          1.0        2.0  Sí  2004.0  1er. Trimestre    NOA
# 7650  125666          1.0        3.0  Sí  2004.0  1er. Trimestre    NOA
# 7651  125666          1.0        4.0  Sí  2004.0  1er. Trimestre    NOA
#
#      mas_500                      aglomerado  pondera  ... deccfr ideccfr  \
# 7647       N  Santiago del Estero - La Banda    238.0  ...     06      06
# 7648       N  Santiago del Estero - La Banda    257.0  ...     02      02
# 7649       N  Santiago del Estero - La Banda    257.0  ...     02      02
# ...
